# %% [markdown]
# Author: Irsyad Adam

# %% [markdown]
# GOAL: extract the summary statistics of every gwas study relating to "heart", "cardiomyopathy", "cardio"... etc
#
# GWAS Catalog API Documentation: https://www.ebi.ac.uk/gwas/rest/docs/api
#
# GWAS API Endpoints Documentation: https://www.ebi.ac.uk/gwas/rest/api
#
# API Endpoint: http://ftp.ebi.ac.uk/pub/databases/gwas/summary_statistics/ + 'Valid GWAS ID'

# %%
import pandas as pd
import os
import requests
from tqdm import tqdm
import ast

# %%
#Final Product: 

# Step 3: run MAGMA using the following command, this takes a GWAS file ${trait}.pval,
# which at least has the columns: SNP, P, N, which corresponds to the SNP id
# (matched to the ${magma_dir}/g1000_eur.bim), p-value, sample size. For example,
# <trait>.pval file looks like
#
# CHR     BP      SNP             P           N
# 1       717587  rs144155419     0.453345    279949
# 1       740284  rs61770167      0.921906    282079
# 1       769223  rs60320384      0.059349    281744

# %%
os.getcwd()
# Out:
# '/Users/pinglab/Documents/irsyadadam/double_injury_scdrs/gwas-catalog-wrapper'

# %%
args = "heart_failure"

folder_name = args
query_file = "%s/%s" % (args, os.listdir(folder_name)[0])
index = pd.read_csv(query_file)
index
# Out:
#         First Author  PubMed ID Study accession Publication date    Journal  \
# 0           Astle WJ   27863252      GCST004623       2016-11-17       Cell
# 1           Astle WJ   27863252      GCST004624       2016-11-17       Cell
# 2           Astle WJ   27863252      GCST004625       2016-11-17       Cell
# 3           Astle WJ   27863252      GCST004600       2016-11-17       Cell
# 4           Astle WJ   27863252      GCST004602       2016-11-17       Cell
# ...              ...        ...             ...              ...        ...
# 30403    de Lange KM   28067908      GCST004133       2017-01-09  Nat Genet
# 30404    de Lange KM   28067908      GCST004131       2017-01-09  Nat Genet
# 30405      Morris AP   22885922      GCST005047       2012-09-01  Nat Genet
# 30406  Michailidou K   29059683      GCST004988       2017-10-23     Nature
# 30407      Verweij N   32916098      GCST010796       2020-09-02  Cell Syst
#
#                                                    Title  \
# 0      The Allelic Landscape of Human Blood Cell Trai...
# 1      The Allelic Landscape of Human Blood Cell Trai...
# 2      The Allelic Landscape of Human Blood Cell Trai...
# 3      The Allelic Landscape of Human Blood Cell Trai...
# 4      The Allelic Landscape of Human Blood Cell Trai...
# ...                                                  ...
# 30403  Genome-wide association study implicates immun...
# 30404  Genome-wide association study implicates immun...
# 30405  Large-scale association analysis provides insi...
# 30406  Association analysis identifies 65 new breast ...
# 30407       The Genetic Makeup of the Electrocardiogram.
#
#                                     Trait(s)  \
# 0      neutrophil percentage of granulocytes
# 1      sum of eosinophil and basophil counts
# 2                             monocyte count
# 3        eosinophil percentage of leukocytes
# 4                    mean corpuscular volume
# ...                                      ...
# 30403                     ulcerative colitis
# 30404             inflammatory bowel disease
# 30405               type 2 diabetes mellitus
# 30406                       breast carcinoma
# 30407                    electrocardiography
#
#                                           Reported trait  \
# 0                  Neutrophil percentage of granulocytes
# 1                         Sum eosinophil basophil counts
# 2                                         Monocyte count
# 3                   Eosinophil percentage of white cells
# 4                                Mean corpuscular volume
# ...                                                  ...
# 30403                                 Ulcerative colitis
# 30404                         Inflammatory bowel disease
# 30405                                    Type 2 diabetes
# 30406                                      Breast cancer
# 30407  Electrocardiogram morphology (amplitude at tem...
#
#                         Data access
# 0      FTP Download  or  API access
# 1      FTP Download  or  API access
# 2      FTP Download  or  API access
# 3      FTP Download  or  API access
# 4      FTP Download  or  API access
# ...                             ...
# 30403  FTP Download  or  API access
# 30404  FTP Download  or  API access
# 30405  FTP Download  or  API access
# 30406  FTP Download  or  API access
# 30407                  FTP Download
#
# [30408 rows x 9 columns]

# %%
#MAIN FUNCTION
def extract_gwas(GWAS_ID) -> None:
    """
    grabs .tsv summary statistics associated with gwas id

    ARGS:
        GWAS_ID is the gwas id of the research

    RETURNS: 
        None
    """
    #get the url
    endpoint = find_endpoint(GWAS_ID)
    print(GWAS_ID, endpoint)
    summary_stats_link = ""

    #if endpointis a range of endpoints
    if len(endpoint) > len(GWAS_ID):
        url = 'http://ftp.ebi.ac.uk/pub/databases/gwas/summary_statistics/' + endpoint + "/" + GWAS_ID + "/"


    #else if single gwas id endpoint
    elif endpoint == GWAS_ID:
        url = 'http://ftp.ebi.ac.uk/pub/databases/gwas/summary_statistics/' + endpoint + "/"
    
    print(url)
    response = requests.get(url=url)
    tsv_file = extract_link(response)
    if tsv_file == None:
            url = url + "harmonised/"
            response = requests.get(url=url)
            tsv_file = extract_link(response)
    summary_stats_link = url + tsv_file


    #TODO: WGET IS SLOOWWWWWW (~2 hours to download)
    cmd = "wget %s" % summary_stats_link
    print(cmd)
    os.system(cmd)

# %%
def extract_link(response: requests.Response) -> str:
    """
    extracts the link from a response from def extract_gwas

    ARGS: 
        response is the http response object

    RETURNS:
        string associated with the link in the response object
    """
    txts = response.text

    #iterate through the lines for the file
    #find first occurance of .tsv file
    #get the link
    for i in txts.splitlines():
        if ".tsv" in i:
            start = '>'
            end = '<'
            link = (i.split(start))[1].split(end)[0]
            return link

# %%
def find_endpoint(GWAS_ID):
    df = pd.read_csv("gwas_catalog_index/index.csv", header = 0)

    #get the index
    ID = int(GWAS_ID[4:])

    endpoint = ""

    #iterate through the id range column
    for i in range(len(df["id_range"])):

        range_ids = ast.literal_eval(df["id_range"][i])
        # CASE1: if the id is in the range column, and range column only has 1 variable
        if len(range_ids) == 1 and range_ids[0] == ID:  
            endpoint = df["endpoints"][i]
            break

        #CASE2 : if id is in between the range, and range column has 2 values
        elif len(range_ids) > 1 and range_ids[0] <= ID <= range_ids[1]:
            endpoint = df["endpoints"][i]
            break
    return str(endpoint)

# %%
extract_gwas("GCST004623")
# Out:
# GCST004623 GCST004001-GCST005000
# http://ftp.ebi.ac.uk/pub/databases/gwas/summary_statistics/GCST004001-GCST005000/GCST004623/
# wget http://ftp.ebi.ac.uk/pub/databases/gwas/summary_statistics/GCST004001-GCST005000/GCST004623/harmonised/27863252-GCST004623-EFO_0007994-Build37.f.tsv.gz
# --2022-07-05 15:29:53--  http://ftp.ebi.ac.uk/pub/databases/gwas/summary_statistics/GCST004001-GCST005000/GCST004623/harmonised/27863252-GCST004623-EFO_0007994-Build37.f.tsv.gz
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.193.138|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1105907181 (1.0G) [application/octet-stream]
# Saving to: ‘27863252-GCST004623-EFO_0007994-Build37.f.tsv.gz’
#
#      0K .......... .......... .......... .......... ..........  0%  176K 1h42m
#     50K .......... .......... .......... .......... ..........  0%  170K 1h43m
#    100K .......... .......... .......... .......... ..........  0%  338K 87m1s
#    150K .......... .......... .......... .......... ..........  0%  336K 78m40s
#    200K .......... .......... .......... .......... ..........  0%  336K 73m38s
#    250K .......... .......... .......... .......... ..........  0%  356K 69m48s
#    300K .......... .......... .......... .......... ..........  0% 4.53M 60m23s
#    350K .......... .......... .......... .......... ..........  0%  335K 59m32s
#    400K .......... .......... .......... .......... ..........  0% 24.9M 53m0s
#    450K .......... .......... .......... .......... ..........  0%  331K 53m7s
#    500K .......... .......... .......... .......... ..........  0% 16.6M 48m23s
#    550K .......... .......... .......... .......... ..........  0%  355K 48m35s
#    600K .......... .......... .......... .......... ..........  0% 2.78M 45m19s
#    650K .......... .......... .......... .......... ..........  0% 67.8M 42m6s
#    700K .......... .......... .......... .......... ..........  0%  332K 42m54s
#    750K .......... .......... .......... .......... ..........  0% 31.8M 40m16s
#    800K .......... .......... .......... .......... ..........  0%  355K 40m52s
#    850K .......... .......... .......... .......... ..........  0% 3.06M 38m55s
#    900K .......... .......... .......... .......... ..........  0% 53.7M 36m53s
#    950K .......... .......... .......... .......... ..........  0%  332K 37m45s
#   1000K .......... .......... .......... .......... ..........  0% 39.4M 35m58s
#   1050K .......... .......... .......... .......... ..........  0%  357K 36m37s
#   1100K .......... .......... .......... .......... ..........  0% 2.96M 35m17s
#   1150K .......... .......... .......... .......... ..........  0% 34.1M 33m50s
#   1200K .......... .......... .......... .......... ..........  0%  324K 34m42s
#   1250K .......... .......... .......... .......... ..........  0% 83.9M 33m23s
#   1300K .......... .......... .......... .......... ..........  0%  324K 34m12s
#   1350K .......... .......... .......... .......... ..........  0% 34.6M 32m59s
#   1400K .......... .......... .......... .......... ..........  0% 31.8M 31m52s
#   1450K .......... .......... .......... .......... ..........  0%  176K 34m13s
#   1500K .......... .......... .......... .......... ..........  0%  178K 36m22s
#   1550K .......... .......... .......... .......... ..........  0%  238K 37m35s
#   1600K .......... .......... .......... .......... ..........  0%  232K 38m48s
#   1650K .......... .......... .......... .......... ..........  0%  239K 39m52s
#   1700K .......... .......... .......... .......... ..........  0%  182K 41m33s
#   1750K .......... .......... .......... .......... ..........  0%  341K 41m52s
#   1800K .......... .......... .......... .......... ..........  0%  229K 42m51s
#   1850K .......... .......... .......... .......... ..........  0%  351K 43m4s
#   1900K .......... .......... .......... .......... ..........  0%  245K 43m50s
#   1950K .......... .......... .......... .......... ..........  0%  232K 44m40s
#   2000K .......... .......... .......... .......... ..........  0%  348K 44m50s
#   2050K .......... .......... .......... .......... ..........  0%  237K 45m34s
#   2100K .......... .......... .......... .......... ..........  0%  349K 45m42s
#   2150K .......... .......... .......... .......... ..........  0%  234K 46m25s
#   2200K .......... .......... .......... .......... ..........  0%  325K 46m36s
#   2250K .......... .......... .......... .......... ..........  0%  350K 46m42s
#   2300K .......... .......... .......... .......... ..........  0%  252K 47m14s
#   2350K .......... .......... .......... .......... ..........  0%  350K 47m19s
#   2400K .......... .......... .......... .......... ..........  0%  239K 47m53s
#   2450K .......... .......... .......... .......... ..........  0%  346K 47m57s
#   2500K .......... .......... .......... .......... ..........  0%  359K 48m0s
#   2550K .......... .......... .......... .......... ..........  0%  351K 48m3s
#   2600K .......... .......... .......... .......... ..........  0%  345K 48m7s
#   2650K .......... .......... .......... .......... ..........  0%  354K 48m10s
#   2700K .......... ..........
